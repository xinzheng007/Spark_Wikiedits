# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from threading import Thread

class StreamingThread(Thread):
    def __init__(self, ssc):
        Thread.__init__(self)
        self.ssc = ssc
    def run(self):
        ssc.start()
        ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.156:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType

# %%
from difflib import unified_diff

def make_diff(old, new):
    return '\n'.join([ l for l in unified_diff(old.split('\n'), new.split('\n')) if l.startswith('+') or l.startswith('-') ])

# %%
globals()['models_loaded'] = False

# ------------ Replace this with a trained ML model
def predict(df):
    if any([x in df.diff.lower() for x in ['bad', 'lol', 'joke']]):
        return 'vandal'
    else:
        return 'safe'
# ------------ Replace this with a trained ML model

predict_udf = udf(predict, StringType())

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df.show()
    
    # Tip: making a diff will probably help a lot as a feature in any model:
    diff = make_diff(df.first().text_old, df.first().text_new)
    df_withdiff = df.withColumn("diff", lit(diff))
    df_withdiff.select('diff').show()
    
    # Utilize our predict function
    df_withpreds = df_withdiff.withColumn("pred", predict_udf(
        struct([df_withdiff[x] for x in df_withdiff.columns])
    ))
    df_withpreds.show()
    
    # Normally, you wouldn't use a UDF (User Defined Function) Python function to predict (you can)
    # But an MLlib model you've built and saved with Spark
    # In this case, you need to prevent loading your model in every call to "process" as follows:
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = '***' # Replace '***' with:    [...].load('my_logistic_regression')
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model: 
    # df_result = globals()['my_model'].transform(df)
    # df_result.show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
# First thing you see is the conversion from the json text to a dataframe --> Can be used for featurization
# Then diff will be computed
# Then we make the prediction
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2020-03-31 20:57:00 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |fixing URL scheme...| safe| S.A. Julio|{{Redirect|Maldin...|{{Redirect|Maldin...|       Paolo Maldini|//en.wikipedia.or...|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|          Alex Close|//en.wikipedia.or...|
# |→‎Government resp...| safe|    Corker1|{{Current event|d...|{{Current event|d...|2020 coronavirus ...|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# - |so...|
# |---
#
# +++
#
# - |so...|
# |---
#
# +++
#
# - |so...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |fixing URL scheme...| safe| S.A. Julio|{{Redirect|Maldin...|{{Redirect|Maldin...|       Paolo Maldini|//en.wikipedia.or...|---
#
# +++
#
# - |so...|safe|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|          Alex Close|//en.wikipedia.or...|---
#
# +++
#
# - |so...|safe|
# |→‎Government resp...| safe|    Corker1|{{Current event|d...|{{Current event|d...|2020 coronavirus ...|//en.wikipedia.or...|---
#
# +++
#
# - |so...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 20:57:10 =========
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|     title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+
# |                    | safe|  Markussep|{{about||the vill...|{{about||the vill...|   Baldovinești|//en.wikipedia.or...|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|Albert Wyckmans|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|ima...|
# |---
#
# +++
#
# -|ima...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|     title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+--------------------+----+
# |                    | safe|  Markussep|{{about||the vill...|{{about||the vill...|   Baldovinești|//en.wikipedia.or...|---
#
# +++
#
# -|ima...|safe|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|Albert Wyckmans|//en.wikipedia.or...|---
#
# +++
#
# -|ima...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+---------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 20:57:20 =========
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|           name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |fixing URL scheme...|  safe|          S.A. Julio|{{About|the men's...|{{About|the men's...|Italy national fo...|//en.wikipedia.or...|
# |                    |unsafe|2601:80:4581:19b0...|{{short descripti...|{{short descripti...|         Ernie Irvan|//en.wikipedia.or...|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -
# -
# -...|
# |---
#
# +++
#
# -
# -
# -...|
# +--------------------+
#
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |             comment| label|           name_user|            text_new|            text_old|          title_page|            url_page|                diff|  pred|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |fixing URL scheme...|  safe|          S.A. Julio|{{About|the men's...|{{About|the men's...|Italy national fo...|//en.wikipedia.or...|---
#
# +++
#
# -
# -
# -...|vandal|
# |                    |unsafe|2601:80:4581:19b0...|{{short descripti...|{{short descripti...|         Ernie Irvan|//en.wikipedia.or...|---
#
# +++
#
# -
# -
# -...|vandal|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
#
# ========= 2020-03-31 20:59:20 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             →‎India| safe|     Sid95Q|{{short descripti...|{{short descripti...|List of films abo...|//en.wikipedia.or...|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|      Anna Callebaut|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -*''[...|
# |---
#
# +++
#
# -*''[...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             →‎India| safe|     Sid95Q|{{short descripti...|{{short descripti...|List of films abo...|//en.wikipedia.or...|---
#
# +++
#
# -*''[...|safe|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|      Anna Callebaut|//en.wikipedia.or...|---
#
# +++
#
# -*''[...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 20:59:30 =========
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|   title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+
# |fixing URL scheme...|  safe|    S.A. Julio|{{Use dmy dates|d...|{{Use dmy dates|d...|Iker Casillas|//en.wikipedia.or...|
# |                    |unsafe|93.176.148.173|{{coord|40|21|27|...|{{coord|40|21|27|...|       Nurnus|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -At c...|
# |---
#
# +++
#
# -At c...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|   title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
# |fixing URL scheme...|  safe|    S.A. Julio|{{Use dmy dates|d...|{{Use dmy dates|d...|Iker Casillas|//en.wikipedia.or...|---
#
# +++
#
# -At c...|safe|
# |                    |unsafe|93.176.148.173|{{coord|40|21|27|...|{{coord|40|21|27|...|       Nurnus|//en.wikipedia.or...|---
#
# +++
#
# -At c...|safe|
# +--------------------+------+--------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 20:59:50 =========
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|  title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|'''Anja Nobus''' ...|  Anja Nobus|//en.wikipedia.or...|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|Anja Lenaers|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |             comment|label|  name_user|            text_new|            text_old|  title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|'''Anja Nobus''' ...|  Anja Nobus|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |→‎top:added short...| safe|Lepricavark|{{short descripti...|{{Use dmy dates|d...|Anja Lenaers|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+-----------+--------------------+--------------------+------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 21:00:00 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |→‎top:added short...| safe|  Lepricavark|{{short descripti...|{{Infobox cyclist...|       Andy Cappelle|//en.wikipedia.or...|
# |Anngela->Angela -...| safe|Bellowhead678|{{DISPLAYTITLE:Li...|{{DISPLAYTITLE:Li...|List of literary ...|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +{{sh...|
# |---
#
# +++
#
# +{{sh...|
# +--------------------+
#
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎top:added short...| safe|  Lepricavark|{{short descripti...|{{Infobox cyclist...|       Andy Cappelle|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# |Anngela->Angela -...| safe|Bellowhead678|{{DISPLAYTITLE:Li...|{{DISPLAYTITLE:Li...|List of literary ...|//en.wikipedia.or...|---
#
# +++
#
# +{{sh...|safe|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-03-31 21:00:30 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |improve an existi...| safe|     Forbes72|In [[theoretical ...|In [[theoretical ...|Whitehead's theor...|//en.wikipedia.or...|
# |→‎2002–2007:fixin...| safe|   S.A. Julio|{{Redirect|2Sides...|{{Redirect|2Sides...|       Rio Ferdinand|//en.wikipedia.or...|
# |→‎top:added short...| safe|  Lepricavark|{{short descripti...|{{Use dmy dates|d...|        André Vlayen|//en.wikipedia.or...|
# |Annimation->Anima...| safe|Bellowhead678|'''''Poetry film'...|'''''Poetry film'...|         Poetry film|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|     name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+
# |                    | safe|AnotherWhisker|{{short descripti...|{{short descripti...|2019–20 coronavir...|//en.wikipedia.or...|
# |syntax, per Webst...| safe|    Nedhartley|{{BLP sources|dat...|{{BLP sources|dat...|           Jem Cohen|//en.wikipedia.or...|
# |→‎Discography:del...| safe|        Michig|{{Use American En...|{{Use American En...|      Ivan & Alyosha|//en.wikipedia.or...|
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| co...|
# |---
#
# +++
#
# -| co...|
# |---
#
# +++
#
# -| co...|
# +--------------------+
#
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|     name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                    | safe|AnotherWhisker|{{short descripti...|{{short descripti...|2019–20 coronavir...|//en.wikipedia.or...|---
#
# +++
#
# -| co...|safe|
# |syntax, per Webst...| safe|    Nedhartley|{{BLP sources|dat...|{{BLP sources|dat...|           Jem Cohen|//en.wikipedia.or...|---
#
# +++
#
# -| co...|safe|
# |→‎Discography:del...| safe|        Michig|{{Use American En...|{{Use American En...|      Ivan & Alyosha|//en.wikipedia.or...|---
#
# +++
#
# -| co...|safe|
# +--------------------+-----+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-03-28 17:14:50 =========
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+
# |comment|label|    name_user|            text_new|            text_old|  title_page|            url_page|
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+
# |       | safe|Ghettoblaster|{{About-distingui...|{{About-distingui...|Apache Samza|//en.wikipedia.or...|
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -{{mo...|
# +--------------------+
#
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |comment|label|    name_user|            text_new|            text_old|  title_page|            url_page|                diff|pred|
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+--------------------+----+
# |       | safe|Ghettoblaster|{{About-distingui...|{{About-distingui...|Apache Samza|//en.wikipedia.or...|---
#
# +++
#
# -{{mo...|safe|
# +-------+-----+-------------+--------------------+--------------------+------------+--------------------+--------------------+----+
